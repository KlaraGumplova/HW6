# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

print(df) 
import matplotlib.pyplot as plt
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  158.779999  160.729996  158.330002  160.619995  156.924393
# 1    2020-01-03  158.320007  159.949997  158.059998  158.619995  154.970413
# 2    2020-01-06  157.080002  159.100006  156.509995  159.029999  155.370972
# 3    2020-01-07  159.320007  159.669998  157.320007  157.580002  153.954376
# 4    2020-01-08  158.929993  160.800003  157.949997  160.089996  156.406570
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-12-24  221.419998  223.610001  221.199997  222.750000  219.930283
# 249  2020-12-28  224.449997  226.029999  223.020004  224.960007  222.112350
# 250  2020-12-29  226.309998  227.179993  223.580002  224.149994  221.312592
# 251  2020-12-30  225.229996  225.630005  221.470001  221.679993  218.873856
# 252  2020-12-31  221.699997  223.000000  219.679993  222.419998  219.604492
#
#        Volume
# 0    22622100
# 1    21116200
# ...

# %%
ClosingPrice =df['Close'].plot(grid =True)
plt.title('Microsoft closing prices for the period 1 Jan 2020 to 1 Jan 2021')
plt.show()
